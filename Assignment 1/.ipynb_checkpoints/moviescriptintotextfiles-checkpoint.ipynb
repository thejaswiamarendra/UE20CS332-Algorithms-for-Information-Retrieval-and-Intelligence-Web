# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
df = pd.read_csv('moviescript.csv')

# %%
noscript = []

for i in range(0, len(df)):
    url = df['URL'].iloc[i]
    title = df['Title'].iloc[i]
    r = requests.get(url)

    soup = BeautifulSoup(r.content, 'html.parser') 

    for j in soup.findAll("pre"):
        if len(j.text)>10000:
            f = open("moviescript/"+title+".txt", "w", encoding="utf-8")
            f.write(j.text)
            f.close()
            break
#     print(url, len(j.text))
    
    if len(j.text) == 0:
        noscript.append(url)
    print(str(i/len(df))[:4]+"%", end="\r")
# Out:
# 0.01%
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Input In [81], in <cell line: 3>()
#      13 #     print(url, len(j.text))
#      14     f = open("moviescript/"+title+".txt", "w")
# ---> 15     f.write(j.text)
#      16     f.close()
#      17     if len(j.text) == 0:
#
# File ~\anaconda3\lib\encodings\cp1252.py:19, in IncrementalEncoder.encode(self, input, final)
#      18 def encode(self, input, final=False):
# ---> 19     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 5076-5077: character maps to <undefined>

# %%
noscript
# Out:
# ['https://imsdb.com/scripts/1492:-Conquest-of-Paradise.html',
#  'https://imsdb.com/scripts/2001:-A-Space-Odyssey.html',
#  'https://imsdb.com/scripts/8-Mile.html',
#  'https://imsdb.com/scripts/Ace-Ventura:-Pet-Detective.html',
#  'https://imsdb.com/scripts/Airplane-2:-The-Sequel.html',
#  'https://imsdb.com/scripts/Alien:-Resurrection.html',
#  'https://imsdb.com/scripts/American-Shaolin:-King-of-Kickboxers-II.html',
#  'https://imsdb.com/scripts/Angels-&-Demons.html',
#  'https://imsdb.com/scripts/Apollo-13.html',
#  'https://imsdb.com/scripts/August:-Osage-County.html',
#  'https://imsdb.com/scripts/Back-to-the-Future.html',
#  'https://imsdb.com/scripts/Back-to-the-Future-II-&-III.html',
#  'https://imsdb.com/scripts/Battle:-Los-Angeles.html',
#  'https://imsdb.com/scripts/Benny-&-Joon.html',
#  'https://imsdb.com/scripts/Blade:-Trinity.html',
#  'https://imsdb.com/scripts/Blues-Brothers,-The.html',
#  'https://imsdb.com/scripts/Bodies,-Rest-&-Motion.html',
#  'https://imsdb.com/scripts/Boondock-Saints-2:-All-Saints-Day.html',
#  'https://imsdb.com/scripts/Celeste-&-Jesse-Forever.html',
#  'https://imsdb.com/scripts/Chronicles-of-Narnia:-The-Lion,-the-Witch-and-the-Wardrobe.html',
#  "https://imsdb.com/scripts/Cirque-du-Freak:-The-Vampire's-Assistant.html",
#  'https://imsdb.com/scripts/Clockwork-Orange,-A.html',
#  'https://imsdb.com/scripts/Commando.html',
#  'https://imsdb.com/scripts/Conan-the-Barbarian.html',
#  'https://imsdb.com/scripts/Courage-Under-Fire.html',
#  'https://imsdb.com/scripts/Cowboys-&-Aliens.html',
#  'https://imsdb.com/scripts/Crow:-City-of-Angels,-The.html',
#  'https://imsdb.com/scripts/Elizabeth:-The-Golden-Age.html',
#  'https://imsdb.com/scripts/Equilibrium.html',
#  'https://imsdb.com/scripts/Evil-Dead-II:-Dead-by-Dawn.html',
#  'https://imsdb.com/scripts/eXistenZ.html',
#  'https://imsdb.com/scripts/Frankenstein.html',
#  'https://imsdb.com/scripts/Frankenweenie.html',
#  'https://imsdb.com/scripts/Friday-the-13th-Part-VIII:-Jason-Takes-Manhattan.html',
#  'https://imsdb.com/scripts/G.I.-Joe:-The-Rise-of-Cobra.html',
#  'https://imsdb.com/scripts/Halloween:-The-Curse-of-Michael-Myers.html',
#  'https://imsdb.com/scripts/Hellbound:-Hellraiser-II.html',
#  'https://imsdb.com/scripts/Hellboy-2:-The-Golden-Army.html',
#  'https://imsdb.com/scripts/Hellraiser-3:-Hell-on-Earth.html',
#  'https://imsdb.com/scripts/Hellraiser:-Deader.html',
#  'https://imsdb.com/scripts/Hellraiser:-Hellseeker.html',
#  'https://imsdb.com/scripts/Highlander:-Endgame.html',
#  'https://imsdb.com/scripts/How-to-Lose-Friends-&-Alienate-People.html',
#  'https://imsdb.com/scripts/Jade.html',
#  'https://imsdb.com/scripts/Jurassic-Park:-The-Lost-World.html',
#  'https://imsdb.com/scripts/Kate-&-Leopold.html',
#  'https://imsdb.com/scripts/Kill-Bill-Volume-1-&-2.html',
#  'https://imsdb.com/scripts/Kiss-of-the-Spider-Woman.html',
#  'https://imsdb.com/scripts/Lion-King,-The.html',
#  'https://imsdb.com/scripts/Lord-of-the-Rings:-Fellowship-of-the-Ring,-The.html',
#  'https://imsdb.com/scripts/Lord-of-the-Rings:-Return-of-the-King.html',
#  'https://imsdb.com/scripts/Lord-of-the-Rings:-The-Two-Towers.html',
#  'https://imsdb.com/scripts/Mad-Max-2:-The-Road-Warrior.html',
#  'https://imsdb.com/scripts/Marley-&-Me.html',
#  'https://imsdb.com/scripts/Mighty-Morphin-Power-Rangers:-The-Movie.html',
#  "https://imsdb.com/scripts/Monster's-Ball.html",
#  "https://imsdb.com/scripts/Mr.-Holland's-Opus.html",
#  'https://imsdb.com/scripts/Nightmare-on-Elm-Street:-The-Final-Chapter.html',
#  'https://imsdb.com/scripts/Officer-and-a-Gentleman,-An.html',
#  'https://imsdb.com/scripts/Papadopoulos-&-Sons.html',
#  "https://imsdb.com/scripts/Pirates-of-the-Caribbean:-Dead-Man's-Chest.html",
#  'https://imsdb.com/scripts/Pokemon:-Mewtwo-Returns.html',
#  'https://imsdb.com/scripts/Rambo:-First-Blood-II:-The-Mission.html',
#  'https://imsdb.com/scripts/Robin-Hood:-Prince-of-Thieves.html',
#  'https://imsdb.com/scripts/Robocop.html',
#  'https://imsdb.com/scripts/Romeo-&-Juliet.html',
#  'https://imsdb.com/scripts/Scary-Movie-2.html',
#  'https://imsdb.com/scripts/Shadow-of-the-Vampire.html',
#  'https://imsdb.com/scripts/Sneakers.html',
#  'https://imsdb.com/scripts/Speed.html',
#  'https://imsdb.com/scripts/Star-Trek-II:-The-Wrath-of-Khan.html',
#  'https://imsdb.com/scripts/Star-Trek:-First-Contact.html',
#  'https://imsdb.com/scripts/Star-Trek:-Generations.html',
#  'https://imsdb.com/scripts/Star-Trek:-Nemesis.html',
#  'https://imsdb.com/scripts/Star-Trek:-The-Motion-Picture.html',
#  'https://imsdb.com/scripts/Star-Wars:-A-New-Hope.html',
#  'https://imsdb.com/scripts/Star-Wars:-Attack-of-the-Clones.html',
#  'https://imsdb.com/scripts/Star-Wars:-Return-of-the-Jedi.html',
#  'https://imsdb.com/scripts/Star-Wars:-Revenge-of-the-Sith.html',
#  'https://imsdb.com/scripts/Star-Wars:-The-Empire-Strikes-Back.html',
#  'https://imsdb.com/scripts/Star-Wars:-The-Force-Awakens.html',
#  'https://imsdb.com/scripts/Star-Wars:-The-Phantom-Menace.html',
#  'https://imsdb.com/scripts/Superfights.html',
#  'https://imsdb.com/scripts/Sweeney-Todd:-The-Demon-Barber-of-Fleet-Street.html',
#  'https://imsdb.com/scripts/Terminator-2:-Judgement-Day.html',
#  'https://imsdb.com/scripts/The-Rage:-Carrie-2.html',
#  'https://imsdb.com/scripts/Thelma-&-Louise.html',
#  'https://imsdb.com/scripts/This-is-40.html',
#  'https://imsdb.com/scripts/Transformers:-The-Movie.html',
#  'https://imsdb.com/scripts/TRON:-Legacy.html',
#  'https://imsdb.com/scripts/Twilight:-New-Moon.html',
#  'https://imsdb.com/scripts/Vertigo.html',
#  'https://imsdb.com/scripts/Wall-Street:-Money-Never-Sleeps.html',
#  'https://imsdb.com/scripts/When-Harry-Met-Sally.html',
#  'https://imsdb.com/scripts/Wild-Things:-Diamonds-in-the-Rough.html',
#  'https://imsdb.com/scripts/X-Files:-Fight-the-Future,-The.html',
#  'https://imsdb.com/scripts/X-Men-Origins:-Wolverine.html']

# %%
bad
# Out:
# {'https://imsdb.com/scripts/12.html': 2,
#  'https://imsdb.com/scripts/1492:-Conquest-of-Paradise.html': 0,
#  'https://imsdb.com/scripts/2001:-A-Space-Odyssey.html': 0,
#  'https://imsdb.com/scripts/48-Hrs..html': 2,
#  'https://imsdb.com/scripts/8-Mile.html': 0,
#  'https://imsdb.com/scripts/Ace-Ventura:-Pet-Detective.html': 0,
#  'https://imsdb.com/scripts/Airplane-2:-The-Sequel.html': 0,
#  'https://imsdb.com/scripts/Alien.html': 3703,
#  'https://imsdb.com/scripts/Alien:-Resurrection.html': 0,
#  'https://imsdb.com/scripts/Almost-Famous.html': 2,
#  'https://imsdb.com/scripts/American-Shaolin:-King-of-Kickboxers-II.html': 0,
#  'https://imsdb.com/scripts/Angels-&-Demons.html': 0,
#  'https://imsdb.com/scripts/Apartment,-The.html': 2,
#  'https://imsdb.com/scripts/Apollo-13.html': 0,
#  'https://imsdb.com/scripts/August:-Osage-County.html': 0,
#  'https://imsdb.com/scripts/Back-to-the-Future.html': 0,
#  'https://imsdb.com/scripts/Back-to-the-Future-II-&-III.html': 0,
#  'https://imsdb.com/scripts/Battle-of-Algiers,-The.html': 2,
#  'https://imsdb.com/scripts/Battle:-Los-Angeles.html': 0,
#  'https://imsdb.com/scripts/Benny-&-Joon.html': 0,
#  'https://imsdb.com/scripts/Blade-II.html': 2,
#  'https://imsdb.com/scripts/Blade:-Trinity.html': 0,
#  'https://imsdb.com/scripts/Blast-from-the-Past,-The.html': 2,
#  'https://imsdb.com/scripts/Blues-Brothers,-The.html': 0,
#  'https://imsdb.com/scripts/Bodies,-Rest-&-Motion.html': 0,
#  'https://imsdb.com/scripts/Boondock-Saints-2:-All-Saints-Day.html': 0,
#  'https://imsdb.com/scripts/Bottle-Rocket.html': 2,
#  'https://imsdb.com/scripts/Brazil.html': 2,
#  'https://imsdb.com/scripts/Buffy-the-Vampire-Slayer.html': 2,
#  'https://imsdb.com/scripts/Celeste-&-Jesse-Forever.html': 0,
#  'https://imsdb.com/scripts/Chronicles-of-Narnia:-The-Lion,-the-Witch-and-the-Wardrobe.html': 0,
#  'https://imsdb.com/scripts/Cinema-Paradiso.html': 2,
#  "https://imsdb.com/scripts/Cirque-du-Freak:-The-Vampire's-Assistant.html": 0,
#  'https://imsdb.com/scripts/Clockwork-Orange,-A.html': 0,
#  'https://imsdb.com/scripts/Clueless.html': 5,
#  'https://imsdb.com/scripts/Commando.html': 0,
#  'https://imsdb.com/scripts/Conan-the-Barbarian.html': 0,
#  'https://imsdb.com/scripts/Courage-Under-Fire.html': 0,
#  'https://imsdb.com/scripts/Cowboys-&-Aliens.html': 0,
#  'https://imsdb.com/scripts/Crow-Salvation,-The.html': 2,
#  'https://imsdb.com/scripts/Crow:-City-of-Angels,-The.html': 0,
#  'https://imsdb.com/scripts/Crying-Game.html': 2,
#  'https://imsdb.com/scripts/Elizabeth:-The-Golden-Age.html': 0,
#  'https://imsdb.com/scripts/Enemy-of-the-State.html': 2,
#  'https://imsdb.com/scripts/Equilibrium.html': 0,
#  'https://imsdb.com/scripts/Evil-Dead-II:-Dead-by-Dawn.html': 0,
#  'https://imsdb.com/scripts/eXistenZ.html': 0,
#  'https://imsdb.com/scripts/Frankenstein.html': 0,
#  'https://imsdb.com/scripts/Frankenweenie.html': 0,
#  'https://imsdb.com/scripts/Frequency.html': 2,
#  'https://imsdb.com/scripts/Friday-the-13th-Part-VIII:-Jason-Takes-Manhattan.html': 0,
#  'https://imsdb.com/scripts/G.I.-Joe:-The-Rise-of-Cobra.html': 0,
#  'https://imsdb.com/scripts/Halloween:-The-Curse-of-Michael-Myers.html': 0,
#  'https://imsdb.com/scripts/Heavy-Metal.html': 2,
#  'https://imsdb.com/scripts/Hellbound:-Hellraiser-II.html': 0,
#  'https://imsdb.com/scripts/Hellboy-2:-The-Golden-Army.html': 0,
#  'https://imsdb.com/scripts/Hellraiser-3:-Hell-on-Earth.html': 0,
#  'https://imsdb.com/scripts/Hellraiser:-Deader.html': 0,
#  'https://imsdb.com/scripts/Hellraiser:-Hellseeker.html': 0,
#  'https://imsdb.com/scripts/Highlander:-Endgame.html': 0,
#  'https://imsdb.com/scripts/How-to-Lose-Friends-&-Alienate-People.html': 0,
#  'https://imsdb.com/scripts/Jade.html': 0,
#  'https://imsdb.com/scripts/Jurassic-Park-III.html': 24,
#  'https://imsdb.com/scripts/Jurassic-Park:-The-Lost-World.html': 0,
#  'https://imsdb.com/scripts/Kate-&-Leopold.html': 0,
#  'https://imsdb.com/scripts/Kill-Bill-Volume-1-&-2.html': 0,
#  'https://imsdb.com/scripts/Kiss-of-the-Spider-Woman.html': 0,
#  'https://imsdb.com/scripts/Leaving-Las-Vegas.html': 2,
#  'https://imsdb.com/scripts/Lion-King,-The.html': 0,
#  'https://imsdb.com/scripts/Lord-of-the-Rings:-Fellowship-of-the-Ring,-The.html': 0,
#  'https://imsdb.com/scripts/Lord-of-the-Rings:-Return-of-the-King.html': 0,
#  'https://imsdb.com/scripts/Lord-of-the-Rings:-The-Two-Towers.html': 0,
#  'https://imsdb.com/scripts/Mad-Max-2:-The-Road-Warrior.html': 0,
#  'https://imsdb.com/scripts/Marley-&-Me.html': 0,
#  'https://imsdb.com/scripts/Mighty-Morphin-Power-Rangers:-The-Movie.html': 0,
#  "https://imsdb.com/scripts/Monster's-Ball.html": 0,
#  "https://imsdb.com/scripts/Mr.-Holland's-Opus.html": 0,
#  'https://imsdb.com/scripts/Mystery-Men.html': 2,
#  'https://imsdb.com/scripts/Napoleon-Dynamite.html': 2,
#  'https://imsdb.com/scripts/Neverending-Story,-The.html': 109,
#  'https://imsdb.com/scripts/Nightmare-on-Elm-Street:-The-Final-Chapter.html': 0,
#  'https://imsdb.com/scripts/Nurse-Betty.html': 2,
#  'https://imsdb.com/scripts/Officer-and-a-Gentleman,-An.html': 0,
#  'https://imsdb.com/scripts/Papadopoulos-&-Sons.html': 0,
#  'https://imsdb.com/scripts/Pearl-Harbor.html': 2,
#  "https://imsdb.com/scripts/Pirates-of-the-Caribbean:-Dead-Man's-Chest.html": 0,
#  'https://imsdb.com/scripts/Pokemon:-Mewtwo-Returns.html': 0,
#  'https://imsdb.com/scripts/Punch-Drunk-Love.html': 2,
#  'https://imsdb.com/scripts/Rambo:-First-Blood-II:-The-Mission.html': 0,
#  'https://imsdb.com/scripts/Robin-Hood:-Prince-of-Thieves.html': 0,
#  'https://imsdb.com/scripts/Robocop.html': 0,
#  'https://imsdb.com/scripts/Romeo-&-Juliet.html': 0,
#  'https://imsdb.com/scripts/Scary-Movie-2.html': 0,
#  'https://imsdb.com/scripts/Shadow-of-the-Vampire.html': 0,
#  'https://imsdb.com/scripts/Sixth-Sense,-The.html': 2,
#  'https://imsdb.com/scripts/Sneakers.html': 0,
#  'https://imsdb.com/scripts/Speed.html': 0,
#  'https://imsdb.com/scripts/Star-Trek-II:-The-Wrath-of-Khan.html': 0,
#  'https://imsdb.com/scripts/Star-Trek:-First-Contact.html': 0,
#  'https://imsdb.com/scripts/Star-Trek:-Generations.html': 0,
#  'https://imsdb.com/scripts/Star-Trek:-Nemesis.html': 0,
#  'https://imsdb.com/scripts/Star-Trek:-The-Motion-Picture.html': 0,
#  'https://imsdb.com/scripts/Star-Wars:-A-New-Hope.html': 0,
#  'https://imsdb.com/scripts/Star-Wars:-Attack-of-the-Clones.html': 0,
#  'https://imsdb.com/scripts/Star-Wars:-Return-of-the-Jedi.html': 0,
#  'https://imsdb.com/scripts/Star-Wars:-Revenge-of-the-Sith.html': 0,
#  'https://imsdb.com/scripts/Star-Wars:-The-Empire-Strikes-Back.html': 0,
#  'https://imsdb.com/scripts/Star-Wars:-The-Force-Awakens.html': 0,
#  'https://imsdb.com/scripts/Star-Wars:-The-Phantom-Menace.html': 0,
#  'https://imsdb.com/scripts/Sugar-and-Spice.html': 2,
#  'https://imsdb.com/scripts/Superfights.html': 0,
#  'https://imsdb.com/scripts/Sweeney-Todd:-The-Demon-Barber-of-Fleet-Street.html': 0,
#  'https://imsdb.com/scripts/Swingers.html': 2,
#  'https://imsdb.com/scripts/Terminator-2:-Judgement-Day.html': 0,
#  'https://imsdb.com/scripts/The-Rage:-Carrie-2.html': 0,
#  'https://imsdb.com/scripts/Thelma-&-Louise.html': 0,
#  "https://imsdb.com/scripts/There's-Something-About-Mary.html": 246,
#  'https://imsdb.com/scripts/This-is-40.html': 0,
#  'https://imsdb.com/scripts/Toy-Story.html': 2,
#  'https://imsdb.com/scripts/Transformers:-The-Movie.html': 0,
#  'https://imsdb.com/scripts/Tremors.html': 2,
#  'https://imsdb.com/scripts/TRON:-Legacy.html': 0,
#  'https://imsdb.com/scripts/Twilight:-New-Moon.html': 0,
#  'https://imsdb.com/scripts/Vertigo.html': 0,
#  'https://imsdb.com/scripts/Wall-Street:-Money-Never-Sleeps.html': 0,
#  'https://imsdb.com/scripts/When-Harry-Met-Sally.html': 0,
#  'https://imsdb.com/scripts/Wild-Things:-Diamonds-in-the-Rough.html': 0,
#  'https://imsdb.com/scripts/X-Files:-Fight-the-Future,-The.html': 0,
#  'https://imsdb.com/scripts/X-Men.html': 2,
#  'https://imsdb.com/scripts/X-Men-Origins:-Wolverine.html': 0}

# %%
url = list(bad.keys())[0]

r = requests.get(url)
soup = BeautifulSoup(r.content, 'html.parser')

# %%
tags = {tag.name for tag in soup.find_all()}
print(tags)
# Out:
# {'head', 'br', 'link', 'html', 'td', 'title', 'h1', 'form', 'script', 'table', 'b', 'body', 'span', 'pre', 'input', 'a', 'font', 'tt', 'img', 'meta', 'div', 'tr', 'center'}

# %%
for i in list(bad.keys()):
    url = i
    r = requests.get(url)
    soup = BeautifulSoup(r.content, 'html.parser') 
    for j in soup.findAll('pre'):
        if len(j.text)>10000:
#             print(j.text)
            break
        else:
            print(url, len(j.text))
# Out:
# https://imsdb.com/scripts/1492:-Conquest-of-Paradise.html 0
# https://imsdb.com/scripts/2001:-A-Space-Odyssey.html 0
# https://imsdb.com/scripts/8-Mile.html 0
# https://imsdb.com/scripts/Ace-Ventura:-Pet-Detective.html 0
# https://imsdb.com/scripts/Airplane-2:-The-Sequel.html 0
# https://imsdb.com/scripts/Alien:-Resurrection.html 0
# https://imsdb.com/scripts/American-Shaolin:-King-of-Kickboxers-II.html 0
# https://imsdb.com/scripts/Angels-&-Demons.html 0
# https://imsdb.com/scripts/Apollo-13.html 0
# https://imsdb.com/scripts/August:-Osage-County.html 0
# https://imsdb.com/scripts/Back-to-the-Future.html 0
# https://imsdb.com/scripts/Back-to-the-Future-II-&-III.html 0
# https://imsdb.com/scripts/Battle:-Los-Angeles.html 0
# https://imsdb.com/scripts/Benny-&-Joon.html 0
# https://imsdb.com/scripts/Blade:-Trinity.html 0
# https://imsdb.com/scripts/Blues-Brothers,-The.html 0
# https://imsdb.com/scripts/Bodies,-Rest-&-Motion.html 0
# https://imsdb.com/scripts/Boondock-Saints-2:-All-Saints-Day.html 0
# https://imsdb.com/scripts/Celeste-&-Jesse-Forever.html 0
# https://imsdb.com/scripts/Chronicles-of-Narnia:-The-Lion,-the-Witch-and-the-Wardrobe.html 0
# https://imsdb.com/scripts/Cirque-du-Freak:-The-Vampire's-Assistant.html 0
# https://imsdb.com/scripts/Clockwork-Orange,-A.html 0
# https://imsdb.com/scripts/Commando.html 0
# https://imsdb.com/scripts/Conan-the-Barbarian.html 0
# https://imsdb.com/scripts/Courage-Under-Fire.html 0
# https://imsdb.com/scripts/Cowboys-&-Aliens.html 0
# https://imsdb.com/scripts/Crow:-City-of-Angels,-The.html 0
# https://imsdb.com/scripts/Elizabeth:-The-Golden-Age.html 0
# https://imsdb.com/scripts/Equilibrium.html 0
# https://imsdb.com/scripts/Evil-Dead-II:-Dead-by-Dawn.html 0
# https://imsdb.com/scripts/eXistenZ.html 0
# https://imsdb.com/scripts/Frankenstein.html 0
# https://imsdb.com/scripts/Frankenweenie.html 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [74], in <cell line: 1>()
#       1 for i in list(bad.keys()):
#       2     url = i
# ----> 3     r = requests.get(url)
#       4     soup = BeautifulSoup(r.content, 'html.parser')
#       5     for j in soup.findAll('pre'):
#
# File ~\anaconda3\lib\site-packages\requests\api.py:75, in get(url, params, **kwargs)
#      64 def get(url, params=None, **kwargs):
#      65     r"""Sends a GET request.
#      66
#      67     :param url: URL for the new :class:`Request` object.
#    (...)
#      72     :rtype: requests.Response
#      73     """
# ---> 75     return request('get', url, params=params, **kwargs)
#
# File ~\anaconda3\lib\site-packages\requests\api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
#      60 with sessions.Session() as session:
# ---> 61     return session.request(method=method, url=url, **kwargs)
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     524 send_kwargs = {
#     525     'timeout': timeout,
#     526     'allow_redirects': allow_redirects,
#     527 }
#     528 send_kwargs.update(settings)
# --> 529 resp = self.send(prep, **send_kwargs)
#     531 return resp
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:645, in Session.send(self, request, **kwargs)
#     642 start = preferred_clock()
#     644 # Send the request
# --> 645 r = adapter.send(request, **kwargs)
#     647 # Total elapsed time of the request (approximately)
#     648 elapsed = preferred_clock() - start
#
# File ~\anaconda3\lib\site-packages\requests\adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     438 try:
#     439     if not chunked:
# --> 440         resp = conn.urlopen(
#     441             method=request.method,
#     442             url=url,
#     443             body=request.body,
#     444             headers=request.headers,
#     445             redirect=False,
#     446             assert_same_host=False,
#     447             preload_content=False,
#     448             decode_content=False,
#     449             retries=self.max_retries,
#     450             timeout=timeout
#     451         )
#     453     # Send the request.
#     454     else:
#     455         if hasattr(conn, 'proxy_pool'):
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~\anaconda3\lib\http\client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File ~\anaconda3\lib\http\client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File ~\anaconda3\lib\http\client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File ~\anaconda3\lib\socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File ~\anaconda3\lib\ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File ~\anaconda3\lib\ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# Out:
# 215724
